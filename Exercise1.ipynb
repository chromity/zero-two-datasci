# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
x = np.arange(10)
y = x ** 2
plt.plot(x, y)

# %%
# %%timeit
x = range(10000)
a = max(x)
# Out:
# 1.04 ms ± 11.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
